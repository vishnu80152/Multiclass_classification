# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

# %%
#path of the dataset
DIRECTORY = r'C:\Users\vishn\OneDrive\Desktop\prjects\python\Camera Vision\Multilevelclassification\DATASET'
#classes to classify depending upon how much clsass you are passing to the model.
CATEGORIES = ['Bears','bike','car','horses','humans','pandas']

# %%
data = []

for category in CATEGORIES:
    path = os.path.join(DIRECTORY, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
        label = CATEGORIES.index(category)
        arr = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        new_arr = cv2.resize(arr, (60, 60))
        data.append([new_arr, label])

# %%
data
# Out:
# [[array([[174, 173, 175, ..., 170, 167, 167],
#          [173, 173, 174, ..., 172, 171, 167],
#          [172, 173, 176, ..., 172, 168, 166],
#          ...,
#          [ 68,  37,  54, ...,  40,   5,  75],
#          [ 84,  40,   8, ...,   2,  67,  48],
#          [ 37,  41,  56, ..., 106,  71,  30]], dtype=uint8),
#   0],
#  [array([[133, 132, 138, ..., 128, 134, 147],
#          [135, 133, 147, ..., 126, 138, 149],
#          [136, 131, 145, ..., 124, 134, 151],
#          ...,
#          [ 47,  48, 101, ...,  23,  13,  14],
#          [ 17,   5, 118, ...,  24,  15,   3],
#          [ 23,  73,   8, ...,  14,  15,   1]], dtype=uint8),
#   0],
#  [array([[140, 142, 154, ..., 163, 157, 152],
#          [145, 148, 161, ..., 161, 155, 150],
#          [151, 151, 162, ..., 158, 152, 148],
#          ...,
#          [136, 143, 143, ...,  25,  14,  17],
#          [135, 142, 145, ...,  10,  31,   8],
#          [130, 135, 141, ...,   2,  46,  15]], dtype=uint8),
#   0],
# ...

# %%
data[0][1]
# Out:
# 4

# %%
import random

random.shuffle(data)

# %%
X = []
y = []

# %%
for features, label in data:
    X.append(features)
    y.append(label)

# %%
X = np.array(X)
y = np.array(y)

# %%
X
# Out:
# array([[[170, 172, 173, ..., 157, 153, 150],
#         [171, 172, 174, ..., 157, 156, 150],
#         [173, 175, 177, ..., 163, 156, 152],
#         ...,
#         [ 43,  18,  15, ...,  19,   9, 100],
#         [ 57,  26,  77, ...,  26,  81,  25],
#         [ 20,  66,  17, ...,  54,  77,  92]],
#
#        [[141, 141, 140, ..., 132, 132, 132],
#         [142, 141, 141, ..., 133, 133, 133],
#         [142, 142, 141, ..., 134, 134, 134],
#         ...,
#         [190, 188, 189, ..., 179, 177, 177],
#         [183, 185, 187, ..., 176, 174, 174],
#         [186, 186, 179, ..., 176, 172, 171]],
#
#        [[176, 203, 223, ..., 182, 172, 175],
#         [ 63, 109, 107, ..., 170, 171, 174],
#         [ 70,  32, 124, ..., 170, 167, 180],
#         ...,
#         [228, 228, 221, ..., 204, 208, 200],
#         [226, 221, 234, ..., 235, 228, 172],
#         [167, 194, 157, ..., 223, 226, 210]],
#
#        ...,
#
#        [[219, 220, 220, ..., 220, 220, 218],
# ...

# %%
y
# Out:
# array([0, 3, 2, ..., 2, 1, 2])

# %%
import pickle

# %%
pickle.dump(X, open('X.pkl', 'wb'))
pickle.dump(y, open('y.pkl', 'wb'))
